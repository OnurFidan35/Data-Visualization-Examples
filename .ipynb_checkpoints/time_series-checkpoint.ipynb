# %%
import yfinance as yf
import pandas as pd

# %%
df=yf.download("AAPL",start="2016-01-01",end="2019-08-25")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04 00:00:00+00:00  23.860580  26.337500  26.342501  25.500000
# 2016-01-05 00:00:00+00:00  23.262653  25.677500  26.462500  25.602501
# 2016-01-06 00:00:00+00:00  22.807407  25.174999  25.592501  24.967501
# 2016-01-07 00:00:00+00:00  21.844835  24.112499  25.032499  24.107500
# 2016-01-08 00:00:00+00:00  21.960342  24.240000  24.777500  24.190001
#
# Price                           Open     Volume
# Ticker                          AAPL       AAPL
# Date
# 2016-01-04 00:00:00+00:00  25.652500  270597600
# 2016-01-05 00:00:00+00:00  26.437500  223164000
# 2016-01-06 00:00:00+00:00  25.139999  273829600
# 2016-01-07 00:00:00+00:00  24.670000  324377600
# 2016-01-08 00:00:00+00:00  24.637501  283192000

# %%
df["Close"]
# Out:
# Ticker                          AAPL
# Date
# 2016-01-04 00:00:00+00:00  26.337500
# 2016-01-05 00:00:00+00:00  25.677500
# 2016-01-06 00:00:00+00:00  25.174999
# 2016-01-07 00:00:00+00:00  24.112499
# 2016-01-08 00:00:00+00:00  24.240000
# ...                              ...
# 2019-08-19 00:00:00+00:00  52.587502
# 2019-08-20 00:00:00+00:00  52.590000
# 2019-08-21 00:00:00+00:00  53.160000
# 2019-08-22 00:00:00+00:00  53.115002
# 2019-08-23 00:00:00+00:00  50.660000
#
# [917 rows x 1 columns]

# %%
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Elimizdeki zaman değişkeninin bir zaman değişkeni olduğunu tanımlamamız gerekmektedir yoksa sorun çıkabilir.(Burada zaten tanımış fakat gösterelim)
df["Close"].index
# Out:
# DatetimeIndex(['2016-01-04 00:00:00+00:00', '2016-01-05 00:00:00+00:00',
#                '2016-01-06 00:00:00+00:00', '2016-01-07 00:00:00+00:00',
#                '2016-01-08 00:00:00+00:00', '2016-01-11 00:00:00+00:00',
#                '2016-01-12 00:00:00+00:00', '2016-01-13 00:00:00+00:00',
#                '2016-01-14 00:00:00+00:00', '2016-01-15 00:00:00+00:00',
#                ...
#                '2019-08-12 00:00:00+00:00', '2019-08-13 00:00:00+00:00',
#                '2019-08-14 00:00:00+00:00', '2019-08-15 00:00:00+00:00',
#                '2019-08-16 00:00:00+00:00', '2019-08-19 00:00:00+00:00',
#                '2019-08-20 00:00:00+00:00', '2019-08-21 00:00:00+00:00',
#                '2019-08-22 00:00:00+00:00', '2019-08-23 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=917, freq=None)

# %%
df["Close"].index=pd.DatetimeIndex(df["Close"].index)
df["Close"].head()
# Out:
# Ticker                          AAPL
# Date
# 2016-01-04 00:00:00+00:00  26.337500
# 2016-01-05 00:00:00+00:00  25.677500
# 2016-01-06 00:00:00+00:00  25.174999
# 2016-01-07 00:00:00+00:00  24.112499
# 2016-01-08 00:00:00+00:00  24.240000

# %%
df["Close"].plot();
